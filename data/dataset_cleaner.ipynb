# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

df = pd.read_csv('globalterrorismdb_0522dist.csv', sep=';')
# Delete columns that represent textual information in numbers
df = df.drop(columns = ['country', 'region', 'alternative', 'attacktype1', 'attacktype2', 'attacktype3', 'targtype1', 'targsubtype1', 'corp1', 'target1', 'natlty1',  'targtype2', 'targsubtype2', 'natlty2', 'targtype3', 'targsubtype3', 'natlty3', 'claimmode', 'claimmode2', 'claimmode3', 'weaptype1',  'weapsubtype1', 'weaptype2', 'weapsubtype2', 'weaptype3', 'weapsubtype3',  'weaptype4', 'weapsubtype4', 'propextent', 'propvalue', 'propcomment', 'hostkidoutcome'])

display(df.head())
# Out:
# C:\Users\matas\AppData\Local\Temp\ipykernel_19896\3655305211.py:5: DtypeWarning: Columns (4,31,33,54,61,62,63,70,76,79,90,92,94,96,107,112,114,115,117,118,119,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('globalterrorismdb_0522dist.csv', sep=';')
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1', 'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3', 'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter', 'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent', 'propextent_txt', 'propvalue', 'propcomment', 'ishostkid', 'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert', 'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus', 'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome', 'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related']
#         eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0  197000000001   1970       7     2        NaN         0        NaN
# 1  197000000002   1970       0     0        NaN         0        NaN
# 2  197001000001   1970       1     0        NaN         0        NaN
# 3  197001000002   1970       1     0        NaN         0        NaN
# 4  197001000003   1970       1     0        NaN         0        NaN
#
#           country_txt                   region_txt provstate           city  \
# 0  Dominican Republic  Central America & Caribbean  National  Santo Domingo
# 1              Mexico                North America   Federal    Mexico city
# 2         Philippines               Southeast Asia    Tarlac        Unknown
# 3              Greece               Western Europe    Attica         Athens
# 4               Japan                    East Asia   Fukouka        Fukouka
#
#     latitude   longitude  specificity  vicinity location summary  crit1  \
# 0  18,456792  -69,951164          1.0         0      NaN     NaN      1
# 1  19,371887  -99,086624          1.0         0      NaN     NaN      1
# 2  15,478598  120,599741          4.0         0      NaN     NaN      1
# 3   37,99749   23,762728          1.0         0      NaN     NaN      1
# 4  33,580412  130,396361          1.0         0      NaN     NaN      1
#
#    crit2  crit3  doubtterr alternative_txt  multiple  success  suicide  \
# 0      1      1          0             NaN       0.0        1        0
# 1      1      1          0             NaN       0.0        1        0
# 2      1      1          0             NaN       0.0        1        0
# 3      1      1          0             NaN       0.0        1        0
# 4      1      1         -9             NaN       0.0        1        0
#
#                   attacktype1_txt attacktype2_txt attacktype3_txt  \
# 0                   Assassination             NaN             NaN
# 1     Hostage Taking (Kidnapping)             NaN             NaN
# 2                   Assassination             NaN             NaN
# 3               Bombing/Explosion             NaN             NaN
# 4  Facility/Infrastructure Attack             NaN             NaN
#
#                  targtype1_txt  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
#
#                                     targsubtype1_txt         natlty1_txt  \
# 0                                     Named Civilian  Dominican Republic
# 1  Diplomatic Personnel (outside of embassy, cons...             Belgium
# 2                    Radio Journalist/Staff/Facility       United States
# 3                                  Embassy/Consulate       United States
# 4                                  Embassy/Consulate       United States
#
#   targtype2_txt targsubtype2_txt corp2 target2 natlty2_txt targtype3_txt  \
# 0           NaN              NaN   NaN     NaN         NaN           NaN
# 1           NaN              NaN   NaN     NaN         NaN           NaN
# 2           NaN              NaN   NaN     NaN         NaN           NaN
# 3           NaN              NaN   NaN     NaN         NaN           NaN
# 4           NaN              NaN   NaN     NaN         NaN           NaN
#
#   targsubtype3_txt corp3 target3 natlty3_txt  \
# 0              NaN   NaN     NaN         NaN
# 1              NaN   NaN     NaN         NaN
# 2              NaN   NaN     NaN         NaN
# 3              NaN   NaN     NaN         NaN
# 4              NaN   NaN     NaN         NaN
#
#                                 gname gsubname gname2 gsubname2 gname3  \
# 0                              MANO-D      NaN    NaN       NaN    NaN
# 1  23rd of September Communist League      NaN    NaN       NaN    NaN
# 2                             Unknown      NaN    NaN       NaN    NaN
# 3                             Unknown      NaN    NaN       NaN    NaN
# 4                             Unknown      NaN    NaN       NaN    NaN
#
#   gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  nperps  \
# 0       NaN    NaN          0.0          NaN          NaN           0     NaN
# 1       NaN    NaN          0.0          NaN          NaN           0     7.0
# 2       NaN    NaN          0.0          NaN          NaN           0     NaN
# 3       NaN    NaN          0.0          NaN          NaN           0     NaN
# 4       NaN    NaN          0.0          NaN          NaN           0     NaN
#
#   nperpcap  claimed claimmode_txt  claim2 claimmode2_txt  claim3  \
# 0      NaN      NaN           NaN     NaN            NaN     NaN
# 1      NaN      NaN           NaN     NaN            NaN     NaN
# 2      NaN      NaN           NaN     NaN            NaN     NaN
# 3      NaN      NaN           NaN     NaN            NaN     NaN
# 4      NaN      NaN           NaN     NaN            NaN     NaN
#
#   claimmode3_txt  compclaim weaptype1_txt        weapsubtype1_txt  \
# 0            NaN        NaN       Unknown                     NaN
# 1            NaN        NaN       Unknown                     NaN
# 2            NaN        NaN       Unknown                     NaN
# 3            NaN        NaN    Explosives  Unknown Explosive Type
# 4            NaN        NaN    Incendiary                     NaN
#
#   weaptype2_txt weapsubtype2_txt weaptype3_txt weapsubtype3_txt weaptype4_txt  \
# 0           NaN              NaN           NaN              NaN           NaN
# 1           NaN              NaN           NaN              NaN           NaN
# 2           NaN              NaN           NaN              NaN           NaN
# 3           NaN              NaN           NaN              NaN           NaN
# 4           NaN              NaN           NaN              NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property propextent_txt  ishostkid  nhostkid  nhostkidus nhours  \
# 0       NaN         0            NaN        0.0       NaN         NaN    NaN
# 1       NaN         0            NaN        1.0       1.0         0.0    NaN
# 2       NaN         0            NaN        0.0       NaN         NaN    NaN
# 3       NaN         1            NaN        0.0       NaN         NaN    NaN
# 4       NaN         1            NaN        0.0       NaN         NaN    NaN
#
#    ndays divert kidhijcountry  ransom ransomamt ransomamtus ransompaid  \
# 0    NaN    NaN           NaN     0.0       NaN         NaN        NaN
# 1    NaN    NaN        Mexico     1.0  800000.0         NaN        NaN
# 2    NaN    NaN           NaN     0.0       NaN         NaN        NaN
# 3    NaN    NaN           NaN     0.0       NaN         NaN        NaN
# 4    NaN    NaN           NaN     0.0       NaN         NaN        NaN
#
#    ransompaidus ransomnote hostkidoutcome_txt  nreleased addnotes scite1  \
# 0           NaN        NaN                NaN        NaN      NaN    NaN
# 1           NaN        NaN                NaN        NaN      NaN    NaN
# 2           NaN        NaN                NaN        NaN      NaN    NaN
# 3           NaN        NaN                NaN        NaN      NaN    NaN
# 4           NaN        NaN                NaN        NaN      NaN    NaN
#
#   scite2 scite3 dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0    NaN    NaN     PGIS        0         0         0        0     NaN
# 1    NaN    NaN     PGIS        0         1         1        1     NaN
# 2    NaN    NaN     PGIS       -9        -9         1        1     NaN
# 3    NaN    NaN     PGIS       -9        -9         1        1     NaN
# 4    NaN    NaN     PGIS       -9        -9         1        1     NaN
